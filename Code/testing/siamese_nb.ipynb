# %%
from neuralnetwork.Siamese import Siamese
#from neuralnetwork.Encoder import Encoder
from torchsummary import summary
from torchviz import make_dot
import torch

# %%
model = Siamese()
input_shape = (4, 17, 17)
summary(model, [input_shape, input_shape])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1              [-1, 8, 8, 8]             296
#        BatchNorm2d-2              [-1, 8, 8, 8]              16
#               ReLU-3              [-1, 8, 8, 8]               0
#             Conv2d-4             [-1, 16, 4, 4]           1,168
#        BatchNorm2d-5             [-1, 16, 4, 4]              32
#               ReLU-6             [-1, 16, 4, 4]               0
#             Conv2d-7             [-1, 32, 2, 2]           4,640
#        BatchNorm2d-8             [-1, 32, 2, 2]              64
#               ReLU-9             [-1, 32, 2, 2]               0
#            Conv2d-10             [-1, 64, 1, 1]          18,496
#       BatchNorm2d-11             [-1, 64, 1, 1]             128
#            Linear-12                   [-1, 64]           4,160
#              ReLU-13                   [-1, 64]               0
# ...

# %%
test_shape = (2, 4, 17, 17)
x1 = torch.randn(test_shape)
x2 = torch.randn(test_shape)
make_dot(model(x1, x2), params=dict(list(model.named_parameters())))
